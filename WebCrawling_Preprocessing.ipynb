# %% [markdown]
# <h1> Web Crawling & NLP Preprocessing : Cornell University Computer Science Paper Abstract  </h1>

# %% [markdown]
# ---
# <h2> 1. 논문 사이트 선정 및 검색법 </h2>
#
# 이용한 논문 사이트는 [Cornell Univerity Library](https://arxiv.org/) 이용했습니다. 위 사이트에는 Physics, Mathematics, Computer Science, Statistics 등등 카테고리별로 분리되어있다. Advanced Search를 이용해 Computer Science 관련된 모든 논문을 검색해보자.
#
#     A. Title -> All fields로 바꾼다.
#     B. Subject를 Computer Science(cs)로 바꾼다.
#     C. 날짜는 All dates
#     D. Abstract를 추출할 것이므로 Show abstracts를 클릭
#     E. Search 클릭

# %% [markdown]
# ---
# <h2> 2. 웹크롤링 만들기 </h2>
#
# 참고한 사이트는 [네이버 실시간 검색어 웹크롤링하기](https://medium.com/@katekim720/%EB%84%A4%EC%9D%B4%EB%B2%84-%EC%8B%A4%EC%8B%9C%EA%B0%84-%EA%B2%80%EC%83%89%EC%96%B4-%EC%9B%B9%ED%81%AC%EB%A1%A4%EB%A7%81%ED%95%98%EA%B8%B0-9d6abf5a7296) 와 PYNEER ITrend 팀 스터디 공유 자료를 참고했다.
#
# +) 쉽게 CSS Selector 만드는 법
#
#     A. Ctrl + Shift + C 를 눌러 Parsing 하고자 하는 부분을 클릭한다.
#
#     B - 1. 해당 태그 오른쪽 버튼 COPY - COPY selector을 클릭한다. 참고 사이트 [나만의 웹 크롤러 만들기 with Requests/BeatufiulSoup]
#            (https://beomi.github.io/2017/01/20/HowToMakeWebCrawler/)
#
#     B - 2. B - 1 방법으로 제대로된 selector을 만들 수 없다면 해당 태그를 누룬 후Styles, Event Listeners 탭들 중 Properties를 클릭한 후 첫번째 요소를 참고한다.
#           ex) 이번 예시에서는 #span#1810.03599v1-abstract-full.abstract-full.has-text-grey-dark.mathjax 가 해당된다.
#
#     C. 원하는 부분을 잘 골라낼 수 있도록 약간 편집한다.
#        ex) #span#1810.03599v1-abstract-full.abstract-full.has-text-grey-dark.mathjax  => abstract-full.has-text-grey-dark.mathjax

# %%
import requests
from bs4 import BeautifulSoup

#웹크롤링하기 위한 사이트 소스를 받아온다.
req = requests.get('https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=200&order=-announced_date_first')
html = req.text

#html.parser란 html 문법 규칙에 따라 문자열의 단어 의미나 구조를 분석하는 것이다.
soup = BeautifulSoup(html, 'html.parser')

#CSS Selector를 통한 원하는 부분 추출
csPaperAbstract = soup.select('span.abstract-full.has-text-grey-dark.mathjax')#abstract-short가 아닌 abstract-full로 가져올 것!
csPaperId = soup.select('p.list-title.level-left')#논문 아이디번호 같이 추출

# %%
import re

#Abstract 과 id 별로 list를 만들어준다.
abstract_list = [abstract.text for abstract in csPaperAbstract]

id_list = []
for ids in csPaperId:
    id_list.append('.'.join(re.findall(r'\b\d+\b', ids.text)[:2]))

# %%
import pandas as pd

#Abstract과 id 별로 DataFrame을 만든다.
ids = pd.DataFrame(id_list, columns=['id'])
abstracts = pd.DataFrame(abstract_list, columns=['raw_text'])

#abstract와 id 를 같이 묶어서 DataFrame을 만듣다.
dp = pd.concat([ids, abstracts], axis = 1)
dp
# Out:
#              id                                           raw_text
# 0    1810.04158  \n        While convolutional neural networks ...
# 1    1810.04152  \n        Deep latent variable models have bec...
# 2    1810.04150  \n        The success of the exascale supercom...
# 3    1810.04147  \n        Building on the success of deep lear...
# 4    1810.04146  \n        In this work, we consider the integr...
# 5    1810.04144  \n        Advanced driver assistance systems a...
# 6    1810.04142  \n        We address fine-grained multilingual...
# 7    1810.04133  \n        Significant advances have been made ...
# 8    1810.04125  \n        We present new algorithms for the ra...
# 9    1810.04119  \n        Cartesian Genetic Programming (CGP) ...
# 10   1810.04118  \n        Smart services are an important elem...
# 11   1810.04114  \n        We propose a general-purpose approac...
# 12   1810.04111  \n        News editors need to find the photos...
# 13   1810.04110  \n        Upcoming HPC clusters will feature h...
# 14   1810.04109  \n        Consider a wireless network where ea...
# 15   1810.04108  \n        Aerator plays an important role in t...
# 16   1810.04107  \n        The development of smart cities and ...
# 17   1810.04101  \n        Image captioning is an interdiscipli...
# 18   1810.04093  \n        Depth estimation from a single image...
# 19   1810.04088  \n        State of the art online learning pro...
# 20   1810.04080  \n        This article presents a multiple sou...
# 21   1810.04077  \n        Point set registration is a powerful...
# 22   1810.04066  \n        We propose a novel deep learning par...
# 23   1810.04064  \n        In recent years, pattern analysis pl...
# 24   1810.04063  \n        General Purpose Graphic Processing U...
# 25   1810.04058  \n        Rebalancing is a critical service bo...
# 26   1810.04053  \n        In the last couple of years, the ris...
# 27   1810.04047  \n        Models optimized for accuracy on sin...
# 28   1810.04041  \n        Capsule Networks (CapsNet) are recen...
# 29   1810.04040  \n        Person-Job Fit is the process of mat...
# ..          ...                                                ...
# 170  1810.03515  \n        We introduce a logic to express stru...
# 171  1810.03513  \n        This paper focuses on showing time-m...
# 172  1810.03510  \n        Covert communication is necessary wh...
# 173  1810.03506  \n        This work introduces an innovative p...
# 174  1810.03505  \n        In this brief technical report we in...
# 175  1810.03498  \n        In this work, we use percolation the...
# 176  1810.03491  \n        We consider the problem of increment...
# 177  1810.03488  \n        We propose a coded distributed compu...
# 178  1810.03487  \n        Recent work has introduced attacks t...
# 179  1810.03480  \n        Text analytics based on supervised m...
# 180  1810.03479  \n        In this paper, we develop a low than...
# 181  1810.03476  \n        Relaying techniques for millimeter-w...
# 182  1810.03473  \n        The mobile femtocell is the new para...
# 183  1810.03470  \n        Multicast/broadcast services (MBS) a...
# 184  1810.03469  \n        The femtocell networks that use home...
# 185  1810.03468  \n        The multiple choices of access netwo...
# 186  1810.03466  \n        This paper proposes a two-stage scor...
# 187  1810.03464  \n        Advanced Persistent Threat (APT) att...
# 188  1810.03459  \n        Sequence-to-sequence (seq2seq) appro...
# 189  1810.03450  \n        We explore active learning (AL) utte...
# 190  1810.03449  \n        The task of event detection involves...
# 191  1810.03445  \n        In this paper, we try to explore the...
# 192  1810.03444  \n        Most state-of-the-art neural machine...
# 193  1810.03436  \n        In this paper we evaluate Optical Ch...
# 194  1810.03430  \n        The text generated on social media p...
# 195  1810.03428  \n        Brain Computer Interfaces (BCIs) bas...
# 196  1810.03427  \n        A detection system with a single sen...
# 197  1810.03426  \n        In an increasingly connected and net...
# 198  1810.03423  \n        Probabilistic argumentation is an al...
# 199  1810.03422  \n        This paper presents a generative mod...
#
# [200 rows x 2 columns]

# %% [markdown]
# ---
# <h2> 3. 전처리 과정 </h2>
#
# 참고 사이트 [인프라 IMDB 영화리뷰 NLP](https://beomi.github.io/2017/01/20/HowToMakeWebCrawler/) 와 [corazzon KaggleStruggle Git](https://github.com/corazzon/KaggleStruggle/blob/master/word2vec-nlp-tutorial/tutorial-part-1.ipynb)

# %%
import nltk
from nltk.corpus import stopwords

def review_to_words( raw_review ):
    #1단계는 여기서 하지 않음
    # 1. HTML 제거
    #review_text = BeautifulSoup(raw_review, 'html.parser').get_text()
    
    # 2. 영문자가 아닌 문자는 공백으로 변환
    letters_only = re.sub('[^a-zA-Z]', ' ', raw_review)
    # 3. 소문자 변환
    words = letters_only.lower().split()
    # 4. 파이썬에서는 리스트보다 세트로 찾는게 훨씬 빠르다.
    # stopwords 를 세트로 변환한다.
    stops = set(stopwords.words('english'))
    # 5. Stopwords 불용어 제거
    meaningful_words = [w for w in words if not w in stops]
    # 6. 어간추출
    stemmer = nltk.stem.PorterStemmer()
    stemming_words = [stemmer.stem(w) for w in meaningful_words]
    # 7. 공백으로 구분된 문자열로 결합하여 결과를 반환
    return( ' '.join(stemming_words) )

#전처리한 내용을 DataFrame에 붙이기
dp['preprossed'] = dp['raw_text'].map(review_to_words)
print(dp)

#CSV 파일로 저장
dp.to_csv('output.csv')
# Out:
#              id                                           raw_text  \
# 0    1810.04158  \n        While convolutional neural networks ...
# 1    1810.04152  \n        Deep latent variable models have bec...
# 2    1810.04150  \n        The success of the exascale supercom...
# 3    1810.04147  \n        Building on the success of deep lear...
# 4    1810.04146  \n        In this work, we consider the integr...
# 5    1810.04144  \n        Advanced driver assistance systems a...
# 6    1810.04142  \n        We address fine-grained multilingual...
# 7    1810.04133  \n        Significant advances have been made ...
# 8    1810.04125  \n        We present new algorithms for the ra...
# 9    1810.04119  \n        Cartesian Genetic Programming (CGP) ...
# 10   1810.04118  \n        Smart services are an important elem...
# 11   1810.04114  \n        We propose a general-purpose approac...
# 12   1810.04111  \n        News editors need to find the photos...
# 13   1810.04110  \n        Upcoming HPC clusters will feature h...
# 14   1810.04109  \n        Consider a wireless network where ea...
# 15   1810.04108  \n        Aerator plays an important role in t...
# 16   1810.04107  \n        The development of smart cities and ...
# 17   1810.04101  \n        Image captioning is an interdiscipli...
# 18   1810.04093  \n        Depth estimation from a single image...
# 19   1810.04088  \n        State of the art online learning pro...
# 20   1810.04080  \n        This article presents a multiple sou...
# 21   1810.04077  \n        Point set registration is a powerful...
# 22   1810.04066  \n        We propose a novel deep learning par...
# 23   1810.04064  \n        In recent years, pattern analysis pl...
# 24   1810.04063  \n        General Purpose Graphic Processing U...
# 25   1810.04058  \n        Rebalancing is a critical service bo...
# 26   1810.04053  \n        In the last couple of years, the ris...
# 27   1810.04047  \n        Models optimized for accuracy on sin...
# 28   1810.04041  \n        Capsule Networks (CapsNet) are recen...
# 29   1810.04040  \n        Person-Job Fit is the process of mat...
# ..          ...                                                ...
# 170  1810.03515  \n        We introduce a logic to express stru...
# 171  1810.03513  \n        This paper focuses on showing time-m...
# 172  1810.03510  \n        Covert communication is necessary wh...
# 173  1810.03506  \n        This work introduces an innovative p...
# 174  1810.03505  \n        In this brief technical report we in...
# 175  1810.03498  \n        In this work, we use percolation the...
# 176  1810.03491  \n        We consider the problem of increment...
# 177  1810.03488  \n        We propose a coded distributed compu...
# 178  1810.03487  \n        Recent work has introduced attacks t...
# 179  1810.03480  \n        Text analytics based on supervised m...
# 180  1810.03479  \n        In this paper, we develop a low than...
# 181  1810.03476  \n        Relaying techniques for millimeter-w...
# 182  1810.03473  \n        The mobile femtocell is the new para...
# 183  1810.03470  \n        Multicast/broadcast services (MBS) a...
# 184  1810.03469  \n        The femtocell networks that use home...
# 185  1810.03468  \n        The multiple choices of access netwo...
# 186  1810.03466  \n        This paper proposes a two-stage scor...
# 187  1810.03464  \n        Advanced Persistent Threat (APT) att...
# 188  1810.03459  \n        Sequence-to-sequence (seq2seq) appro...
# 189  1810.03450  \n        We explore active learning (AL) utte...
# 190  1810.03449  \n        The task of event detection involves...
# 191  1810.03445  \n        In this paper, we try to explore the...
# 192  1810.03444  \n        Most state-of-the-art neural machine...
# 193  1810.03436  \n        In this paper we evaluate Optical Ch...
# 194  1810.03430  \n        The text generated on social media p...
# 195  1810.03428  \n        Brain Computer Interfaces (BCIs) bas...
# 196  1810.03427  \n        A detection system with a single sen...
# 197  1810.03426  \n        In an increasingly connected and net...
# 198  1810.03423  \n        Probabilistic argumentation is an al...
# 199  1810.03422  \n        This paper presents a generative mod...
#
#                                             preprossed
# 0    convolut neural network domin field comput vis...
# 1    deep latent variabl model becom popular model ...
# 2    success exascal supercomput larg debat remain ...
# 3    build success deep learn two modern approach l...
# 4    work consid integr mpi one side commun non blo...
# 5    advanc driver assist system advanc rapid pace ...
# 6    address fine grain multilingu languag identif ...
# 7    signific advanc made recent train neural netwo...
# 8    present new algorithm random construct hierarc...
# 9    cartesian genet program cgp mani modif across ...
# 10   smart servic import element smart citi interne...
# 11   propos gener purpos approach discov activ lear...
# 12   news editor need find photo best illustr news ...
# 13   upcom hpc cluster featur hybrid memori storag ...
# 14   consid wireless network commun link minimum ba...
# 15   aerat play import role regul dissolv oxygen aq...
# 16   develop smart citi fast pace deploy result gen...
# 17   imag caption interdisciplinari research proble...
# 18   depth estim singl imag repres excit challeng c...
# 19   state art onlin learn procedur focu either sel...
# 20   articl present multipl sound sourc local track...
# 21   point set registr power method enabl robot man...
# 22   propos novel deep learn paradigm differenti fl...
# 23   recent year pattern analysi play import role d...
# 24   gener purpos graphic process unit gpgpu use wi...
# 25   rebalanc critic servic bottleneck mani transpo...
# 26   last coupl year rise artifici intellig success...
# 27   model optim accuraci singl imag often prohibit...
# 28   capsul network capsnet recent propos multi sta...
# 29   person job fit process match right talent righ...
# ..                                                 ...
# 170  introduc logic express structur properti autom...
# 171  paper focus show time messag trade off distrib...
# 172  covert commun necessari reveal mere exist mess...
# 173  work introduc innov parallel fulli distribut f...
# 174  brief technic report introduc cinic dataset pl...
# 175  work use percol theori studi feasibl larg scal...
# 176  consid problem increment cycl detect topolog o...
# 177  propos code distribut comput scheme base rapto...
# 178  recent work introduc attack extract architectu...
# 179  text analyt base supervis machin learn classif...
# 180  paper develop low charact featur embed call ra...
# 181  relay techniqu millimet wave wireless network ...
# 182  mobil femtocel new paradigm femtocellular netw...
# 183  multicast broadcast servic mb abl provid video...
# 184  femtocel network use home base station exist x...
# 185  multipl choic access network offer differ oppo...
# 186  paper propos two stage score approach help len...
# 187  advanc persist threat apt attack sophist steal...
# 188  sequenc sequenc seq seq approach low resourc a...
# 189  explor activ learn al utter select improv accu...
# 190  task event detect involv identifi categor even...
# 191  paper tri explor evolut languag case calcul fi...
# 192  state art neural machin translat system despit...
# 193  paper evalu optic charact recognit ocr th cent...
# 194  text gener social media platform essenti mix l...
# 195  brain comput interfac bci base visual evok pot...
# 196  detect system singl sensor two detector consid...
# 197  increasingli connect network world nation aero...
# 198  probabilist argument altern causal model bayes...
# 199  paper present gener model super resolut routin...
#
# [200 rows x 3 columns]
