# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import nltk
from nltk.corpus import stopwords

def review_to_words( raw_review ):
    # 1. 영문자가 아닌 문자는 공백으로 변환
    letters_only = re.sub('[^a-zA-Z]', ' ', raw_review)
    # 2. 소문자 변환
    words = letters_only.lower().split()
    # 3. 파이썬에서는 리스트보다 세트로 찾는게 훨씬 빠르다.
    # stopwords 를 세트로 변환한다.
    stops = set(stopwords.words('english'))
    # 4. Stopwords 불용어 제거
    meaningful_words = [w for w in words if not w in stops]
    # 5. 어간추출
    stemmer = nltk.stem.PorterStemmer()
    stemming_words = [stemmer.stem(w) for w in meaningful_words]
    # 6. 공백으로 구분된 문자열로 결합하여 결과를 반환
    return( ' '.join(stemming_words) )

abstract_list=[]
id_list = []
page_num = 5 #파싱해야하는 페이지 총 수(700개가 넘지만 일단 5페이지만)

#웹크롤링하기 위한 사이트 소스를 받아온다.
for i in range(page_num):
    print(str(i*200))#어느정도 파싱이 되었는지 확인용도
    #페이지별로 일정하게 변하는 URL 규칙을 확인하여 소스를 받아온다.
    req = requests.get(
        'https://arxiv.org/search/advanced?advanced=1&terms-0-operator=AND&terms-0-term=&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=200&order=-announced_date_first&start=' + str(i*200))
    html = req.text

    # html.parser란 html 문법 규칙에 따라 문자열의 단어 의미나 구조를 분석하는 것이다.
    soup = BeautifulSoup(html, 'html.parser')

    # CSS Selector를 통한 원하는 부분 추출
    csPaperAbstract = soup.select(
        'span.abstract-full.has-text-grey-dark.mathjax')  # abstract-short가 아닌 abstract-full로 가져올 것!
    csPaperId = soup.select('p.list-title.level-left')  # 논문 아이디번호 같이 추출

    # Abstract 과 id 별로 list를 만들어준다.
    for abstract in csPaperAbstract:
        abstract_list.append(abstract.text)
    for ids in csPaperId:
        id_list.append('.'.join(re.findall(r'\b\d+\b', ids.text)[:2]))
# Out:
# 0
# 200
# 400
# 600
# 800

# %%
# Abstract과 id 별로 DataFrame을 만든다.
ids = pd.DataFrame({'id': id_list})
abstracts = pd.DataFrame({'raw_text': abstract_list})

# abstract와 id 를 같이 묶어서 DataFrame을 만듣다.
dp = pd.concat([ids, abstracts], axis=1)
# 전처리한 내용을 DataFrame에 붙이기
dp['preprossed'] = dp['raw_text'].map(review_to_words)
dp
# Out:
#              id                                           raw_text  \
# 0    1810.04158  \n        While convolutional neural networks ...
# 1    1810.04152  \n        Deep latent variable models have bec...
# 2    1810.04150  \n        The success of the exascale supercom...
# 3    1810.04147  \n        Building on the success of deep lear...
# 4    1810.04146  \n        In this work, we consider the integr...
# 5    1810.04144  \n        Advanced driver assistance systems a...
# 6    1810.04142  \n        We address fine-grained multilingual...
# 7    1810.04133  \n        Significant advances have been made ...
# 8    1810.04125  \n        We present new algorithms for the ra...
# 9    1810.04119  \n        Cartesian Genetic Programming (CGP) ...
# 10   1810.04118  \n        Smart services are an important elem...
# 11   1810.04114  \n        We propose a general-purpose approac...
# 12   1810.04111  \n        News editors need to find the photos...
# 13   1810.04110  \n        Upcoming HPC clusters will feature h...
# 14   1810.04109  \n        Consider a wireless network where ea...
# 15   1810.04108  \n        Aerator plays an important role in t...
# 16   1810.04107  \n        The development of smart cities and ...
# 17   1810.04101  \n        Image captioning is an interdiscipli...
# 18   1810.04093  \n        Depth estimation from a single image...
# 19   1810.04088  \n        State of the art online learning pro...
# 20   1810.04080  \n        This article presents a multiple sou...
# 21   1810.04077  \n        Point set registration is a powerful...
# 22   1810.04066  \n        We propose a novel deep learning par...
# 23   1810.04064  \n        In recent years, pattern analysis pl...
# 24   1810.04063  \n        General Purpose Graphic Processing U...
# 25   1810.04058  \n        Rebalancing is a critical service bo...
# 26   1810.04053  \n        In the last couple of years, the ris...
# 27   1810.04047  \n        Models optimized for accuracy on sin...
# 28   1810.04041  \n        Capsule Networks (CapsNet) are recen...
# 29   1810.04040  \n        Person-Job Fit is the process of mat...
# ..          ...                                                ...
# 970  1810.00362  \n        Facial expression is the most natura...
# 971  1810.00361  \n        Learning in sparse reward settings r...
# 972  1810.00360  \n        Bag-of-Visual-Words (BoVW) approach ...
# 973  1810.00358  \n        The landscape of analytics is changi...
# 974  1810.00357  \n        There have been many proposals for a...
# 975  1810.00356  \n        Advances in network programmability ...
# 976  1810.00352  \n        We aim to enable a mobile robot to n...
# 977  1810.00349  \n        Today, Internet of Things (IoT) devi...
# 978  1810.00347  \n        We propose Neural Entity Reasoner (N...
# 979  1810.00345  \n        Annotating large scale datasets to t...
# 980  1810.00341  \n        In this paper, we introduce a novel ...
# 981  1810.00337  \n        For problem solving, making reactive...
# 982  1810.00333  \n        In this paper we study empirically t...
# 983  1810.00329  \n        Blockchain technology is growing eve...
# 984  1810.00327  \n        Accurate and reliable image segmenta...
# 985  1810.00326  \n        We propose the use of Graph-Pattern ...
# 986  1810.00324  \n        The Winograd Schema (WS) challenge h...
# 987  1810.00322  \n        Ultrasound elastography is gaining t...
# 988  1810.00319  \n        Instance embeddings are an efficient...
# 989  1810.00318  \n        In this paper, we study the problem ...
# 990  1810.00314  \n        The way developers edit day-to-day c...
# 991  1810.00313  \n        We present a method for synthesizing...
# 992  1810.00308  \n        The emergence of RGB-D sensors offer...
# 993  1810.00307  \n        Training convolutional neural networ...
# 994  1810.00305  \n        Contrary to using distant and centra...
# 995  1810.00304  \n        In this work, we propose a novel hyb...
# 996  1810.00302  \n        Dynamic MR image reconstruction from...
# 997  1810.00300  \n        The relentless development of the In...
# 998  1810.00299  \n        Advances in designing and training d...
# 999  1810.00298  \n        We deal with zero-delay source codin...
#
#                                             preprossed
# 0    convolut neural network domin field comput vis...
# 1    deep latent variabl model becom popular model ...
# 2    success exascal supercomput larg debat remain ...
# 3    build success deep learn two modern approach l...
# 4    work consid integr mpi one side commun non blo...
# 5    advanc driver assist system advanc rapid pace ...
# 6    address fine grain multilingu languag identif ...
# 7    signific advanc made recent train neural netwo...
# 8    present new algorithm random construct hierarc...
# 9    cartesian genet program cgp mani modif across ...
# 10   smart servic import element smart citi interne...
# 11   propos gener purpos approach discov activ lear...
# 12   news editor need find photo best illustr news ...
# 13   upcom hpc cluster featur hybrid memori storag ...
# 14   consid wireless network commun link minimum ba...
# 15   aerat play import role regul dissolv oxygen aq...
# 16   develop smart citi fast pace deploy result gen...
# 17   imag caption interdisciplinari research proble...
# 18   depth estim singl imag repres excit challeng c...
# 19   state art onlin learn procedur focu either sel...
# 20   articl present multipl sound sourc local track...
# 21   point set registr power method enabl robot man...
# 22   propos novel deep learn paradigm differenti fl...
# 23   recent year pattern analysi play import role d...
# 24   gener purpos graphic process unit gpgpu use wi...
# 25   rebalanc critic servic bottleneck mani transpo...
# 26   last coupl year rise artifici intellig success...
# 27   model optim accuraci singl imag often prohibit...
# 28   capsul network capsnet recent propos multi sta...
# 29   person job fit process match right talent righ...
# ..                                                 ...
# 970  facial express natur mean human be commun emot...
# 971  learn spars reward set remain challeng reinfor...
# 972  bag visual word bovw approach wide use recent ...
# 973  landscap analyt chang rapidli much onlin user ...
# 974  mani propos algorithm segment human whole bodi...
# 975  advanc network programm enabl oper slice physi...
# 976  aim enabl mobil robot navig environ dens crowd...
# 977  today internet thing iot devic powerhous data ...
# 978  propos neural entiti reason ne reason framewor...
# 979  annot larg scale dataset train modern convolut...
# 980  paper introduc novel natur languag gener task ...
# 981  problem solv make reactiv decis base problem d...
# 982  paper studi empir valid measur referenti succe...
# 983  blockchain technolog grow everyday fast pass r...
# 984  accur reliabl imag segment essenti part biomed...
# 985  propos use graph pattern associ rule gpar yago...
# 986  winograd schema ws challeng propos altern ture...
# 987  ultrasound elastographi gain traction access u...
# 988  instanc embed effici versatil imag represent f...
# 989  paper studi problem continu time state observ ...
# 990  way develop edit day day code tend repetit oft...
# 991  present method synthes control steer trajector...
# 992  emerg rgb sensor offer new possibl address com...
# 993  train convolut neural network cnn requir inten...
# 994  contrari use distant central cloud data center...
# 995  work propos novel hybrid method scene text det...
# 996  dynam mr imag reconstruct incomplet k space da...
# 997  relentless develop internet thing iot commun t...
# 998  advanc design train deep neural network led pr...
# 999  deal zero delay sourc code vector valu gauss m...
#
# [1000 rows x 3 columns]

# %%
dp.to_csv('output.csv', sep=',')

# %% [markdown]
# 하지만 논문 수가 많아질수록 시간도 많이 걸린다. 그러므로 멀티프로세싱을 이용하는 방법을 찾아보자. 이에 대한 포스팅은 다음에 가져오겠습니다.
