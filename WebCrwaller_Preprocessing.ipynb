# %% [markdown]
# <h1> Web Crawlling : Cronell University Computer Science Paper Abstract  </h1>

# %% [markdown]
# ---
# <h2> 1. 논문 사이트 검색법 </h2>
#
# 이용한 논문 사이트는 [Cornell Univerity Library](https://arxiv.org/) 이용했습니다. 위 사이트에는 Physics, Mathematics, Computer Science, Statistics 등등 카테고리별로 분리되어있다. Advanced Search를 이용해 Computer Science 관련된 모든 논문을 검색해보자.
#
#     A. Title -> All fields로 바꾼다.
#     B. Subject를 Computer Science(cs)로 바꾼다.
#     C. 날짜는 All dates
#     D. Abstract를 추출할 것이므로 Show abstracts를 클릭
#     E. Search 클릭

# %% [markdown]
# ---
# <h2> 2. 웹크롤링 만들기 </h2>
#
# 참고한 사이트는 [네이버 실시간 검색어 웹크롤링하기](https://medium.com/@katekim720/%EB%84%A4%EC%9D%B4%EB%B2%84-%EC%8B%A4%EC%8B%9C%EA%B0%84-%EA%B2%80%EC%83%89%EC%96%B4-%EC%9B%B9%ED%81%AC%EB%A1%A4%EB%A7%81%ED%95%98%EA%B8%B0-9d6abf5a7296) 와 저번 NLP 스터디 자료를 참고했다.
#
# +) 쉽게 CSS Selector 만드는 법
#
#     A. Ctrl + Shift + C 를 눌러 Parsing 하고자 하는 부분을 클릭한다.
#
#     B - 1. 해당 태그 오른쪽 버튼 COPY - COPY selector을 클릭한다. 참고 사이트 [나만의 웹 크롤러 만들기 with Requests/BeatufiulSoup]
#            (https://beomi.github.io/2017/01/20/HowToMakeWebCrawler/)
#
#     B - 2. B - 1 방법으로 제대로된 selector을 만들 수 없다면 해당 태그를 누룬 후Styles, Event Listeners 탭들 중 Properties를 클릭한다.
#           ex) 이번 예시에서는 #span#1810.03599v1-abstract-full.abstract-full.has-text-grey-dark.mathjax 가 해당된다.
#
#     C. 적당히 편집한다.
#        ex) #span#1810.03599v1-abstract-full.abstract-full.has-text-grey-dark.mathjax  => abstract-full.has-text-grey-dark.mathjax

# %%
import requests
from bs4 import BeautifulSoup

#웹크롤링하기 위한 사이트 소스를 받아온다.
req = requests.get('https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=200&order=-announced_date_first')
html = req.text

#html.parser란 html 문법 규칙에 따라 문자열의 단어 의미나 구조를 분석하는 것이다.
soup = BeautifulSoup(html, 'html.parser')

#CSS Selector를 통한 원하는 부분 추출
csPaperAbstract = soup.select('span.abstract-full.has-text-grey-dark.mathjax')#abstract-short가 아닌 abstract-full로 가져올 것!
csPaperId = soup.select('p.list-title.level-left')#논문 아이디번호 같이 추출

# %%
import re

#Abstract 과 id 별로 list를 만들어준다.
abstract_list = [abstract.text for abstract in csPaperAbstract]
id_list = []
for ids in csPaperId:
    id_list.append('.'.join(re.findall(r'\b\d+\b', ids.text)[:2]))

# %%
import pandas as pd

#Abstract과 id 별로 DataFrame을 만든다.
ids = pd.DataFrame(id_list, columns=['id'])
abstracts = pd.DataFrame(abstract_list, columns=['raw_text'])

#abstract와 id 를 같이 묶어서 DataFrame을 만듣다.
dp = pd.concat([ids, abstracts], axis = 1)
dp
# Out:
#              id                                           raw_text
# 0    1810.03599  \n        Data-driven character animation base...
# 1    1810.03598  \n        Building on the successes of satisfi...
# 2    1810.03595  \n        For analysing and/or understanding l...
# 3    1810.03594  \n        In online learning, the dynamic regr...
# 4    1810.03587  \n        The traditional approach of hand-cra...
# 5    1810.03583  \n        Robots require knowledge about objec...
# 6    1810.03581  \n        Although the Transformer translation...
# 7    1810.03579  \n        Changes to network structure can sub...
# 8    1810.03572  \n        This paper aims to design quadrotor ...
# 9    1810.03570  \n        Detection of buildings and other obj...
# 10   1810.03568  \n        The widespread adoption of continuou...
# 11   1810.03552  \n        Modern natural language processing a...
# 12   1810.03551  \n        We consider the approximate pattern ...
# 13   1810.03548  \n        Meta-learning, or learning to learn,...
# 14   1810.03541  \n        In this paper, we propose a new rich...
# 15   1810.03538  \n        Binarized Neural Networks (BNNs) hav...
# 16   1810.03530  \n        We present a novel parallelisation s...
# 17   1810.03527  \n        Many hyperparameter optimization (Hy...
# 18   1810.03523  \n        This work studies the problem of lea...
# 19   1810.03522  \n        This paper introduces NSGA-Net, an e...
# 20   1810.03519  \n        In microblog retrieval, query expans...
# 21   1810.03516  \n        Policy search reinforcement learning...
# 22   1810.03515  \n        We introduce a logic to express stru...
# 23   1810.03513  \n        This paper focuses on showing time-m...
# 24   1810.03510  \n        Covert communication is necessary wh...
# 25   1810.03506  \n        This work introduces an innovative p...
# 26   1810.03505  \n        In this brief technical report we in...
# 27   1810.03498  \n        In this work, we use percolation the...
# 28   1810.03491  \n        We consider the problem of increment...
# 29   1810.03488  \n        We propose a coded distributed compu...
# ..          ...                                                ...
# 170  1810.02966  \n        At present, the state-of-the-art com...
# 171  1810.02964  \n        In this paper we break the protocol ...
# 172  1810.02959  \n        Higher-order connectivity patterns s...
# 173  1810.02953  \n        We show that the shuffle $L \unicode...
# 174  1810.02950  \n        In many domains, there is significan...
# 175  1810.02938  \n        Learning a matching function between...
# 176  1810.02937  \n        Decentralization, which has backed t...
# 177  1810.02936  \n        Person re-identification (reID) is a...
# 178  1810.02935  \n        Recent years, many applications have...
# 179  1810.02930  \n        Mechanism design is studied for aggr...
# 180  1810.02929  \n        This paper discusses system conseque...
# 181  1810.02927  \n        Goal-oriented learning has become a ...
# 182  1810.02920  \n        A novel framework is presented that ...
# 183  1810.02919  \n        Efforts are underway at UT Austin to...
# 184  1810.02912  \n        Reinforcement learning in multi-agen...
# 185  1810.02911  \n        We propose a software platform that ...
# 186  1810.02907  \n        Text mining and analytics software h...
# 187  1810.02904  \n        We present a new approach to testing...
# 188  1810.02899  \n        Cloud operators require real-time id...
# 189  1810.02898  \n        This note studies (practical) asympt...
# 190  1810.02897  \n        Many distance-based algorithms exhib...
# 191  1810.02895  \n        Consumer genetic testing has become ...
# 192  1810.02891  \n        Reading comprehension tasks test the...
# 193  1810.02890  \n        Imitation learning has proven to be ...
# 194  1810.02889  \n        We present a framework for generatin...
# 195  1810.02880  \n        In this paper, we introduce a novel ...
# 196  1810.02869  \n        This work is done as part of a maste...
# 197  1810.02862  \n        Haze and smog are among the most com...
# 198  1810.02854  \n        We show that discrete distributions ...
# 199  1810.02851  \n        Auto-encoders compress input data in...
#
# [200 rows x 2 columns]

# %% [markdown]
# ---
# <h2> 3. 전처리 과정 </h2>
#
# 참고 사이트 [인프라 IMDB 영화리뷰 NLP](https://beomi.github.io/2017/01/20/HowToMakeWebCrawler/) 와 [corazzon KaggleStruggle Git](https://github.com/corazzon/KaggleStruggle/blob/master/word2vec-nlp-tutorial/tutorial-part-1.ipynb)

# %%
import nltk
from nltk.corpus import stopwords

def review_to_words( raw_review ):
    # 1. HTML 제거
    review_text = BeautifulSoup(raw_review, 'html.parser').get_text()
    # 2. 영문자가 아닌 문자는 공백으로 변환
    letters_only = re.sub('[^a-zA-Z]', ' ', review_text)
    # 3. 소문자 변환
    words = letters_only.lower().split()
    # 4. 파이썬에서는 리스트보다 세트로 찾는게 훨씬 빠르다.
    # stopwords 를 세트로 변환한다.
    stops = set(stopwords.words('english'))
    # 5. Stopwords 불용어 제거
    meaningful_words = [w for w in words if not w in stops]
    # 6. 어간추출
    stemmer = nltk.stem.PorterStemmer()
    stemming_words = [stemmer.stem(w) for w in meaningful_words]
    # 7. 공백으로 구분된 문자열로 결합하여 결과를 반환
    return( ' '.join(stemming_words) )

#전처리한 내용을 DataFrame에 붙이기
dp['preprossed'] = dp['raw_text'].apply(review_to_words)
print(dp)

#CSV 파일로 저장
dp.to_csv('output.csv')
# Out:
#              id                                           raw_text  \
# 0    1810.03599  \n        Data-driven character animation base...
# 1    1810.03598  \n        Building on the successes of satisfi...
# 2    1810.03595  \n        For analysing and/or understanding l...
# 3    1810.03594  \n        In online learning, the dynamic regr...
# 4    1810.03587  \n        The traditional approach of hand-cra...
# 5    1810.03583  \n        Robots require knowledge about objec...
# 6    1810.03581  \n        Although the Transformer translation...
# 7    1810.03579  \n        Changes to network structure can sub...
# 8    1810.03572  \n        This paper aims to design quadrotor ...
# 9    1810.03570  \n        Detection of buildings and other obj...
# 10   1810.03568  \n        The widespread adoption of continuou...
# 11   1810.03552  \n        Modern natural language processing a...
# 12   1810.03551  \n        We consider the approximate pattern ...
# 13   1810.03548  \n        Meta-learning, or learning to learn,...
# 14   1810.03541  \n        In this paper, we propose a new rich...
# 15   1810.03538  \n        Binarized Neural Networks (BNNs) hav...
# 16   1810.03530  \n        We present a novel parallelisation s...
# 17   1810.03527  \n        Many hyperparameter optimization (Hy...
# 18   1810.03523  \n        This work studies the problem of lea...
# 19   1810.03522  \n        This paper introduces NSGA-Net, an e...
# 20   1810.03519  \n        In microblog retrieval, query expans...
# 21   1810.03516  \n        Policy search reinforcement learning...
# 22   1810.03515  \n        We introduce a logic to express stru...
# 23   1810.03513  \n        This paper focuses on showing time-m...
# 24   1810.03510  \n        Covert communication is necessary wh...
# 25   1810.03506  \n        This work introduces an innovative p...
# 26   1810.03505  \n        In this brief technical report we in...
# 27   1810.03498  \n        In this work, we use percolation the...
# 28   1810.03491  \n        We consider the problem of increment...
# 29   1810.03488  \n        We propose a coded distributed compu...
# ..          ...                                                ...
# 170  1810.02966  \n        At present, the state-of-the-art com...
# 171  1810.02964  \n        In this paper we break the protocol ...
# 172  1810.02959  \n        Higher-order connectivity patterns s...
# 173  1810.02953  \n        We show that the shuffle $L \unicode...
# 174  1810.02950  \n        In many domains, there is significan...
# 175  1810.02938  \n        Learning a matching function between...
# 176  1810.02937  \n        Decentralization, which has backed t...
# 177  1810.02936  \n        Person re-identification (reID) is a...
# 178  1810.02935  \n        Recent years, many applications have...
# 179  1810.02930  \n        Mechanism design is studied for aggr...
# 180  1810.02929  \n        This paper discusses system conseque...
# 181  1810.02927  \n        Goal-oriented learning has become a ...
# 182  1810.02920  \n        A novel framework is presented that ...
# 183  1810.02919  \n        Efforts are underway at UT Austin to...
# 184  1810.02912  \n        Reinforcement learning in multi-agen...
# 185  1810.02911  \n        We propose a software platform that ...
# 186  1810.02907  \n        Text mining and analytics software h...
# 187  1810.02904  \n        We present a new approach to testing...
# 188  1810.02899  \n        Cloud operators require real-time id...
# 189  1810.02898  \n        This note studies (practical) asympt...
# 190  1810.02897  \n        Many distance-based algorithms exhib...
# 191  1810.02895  \n        Consumer genetic testing has become ...
# 192  1810.02891  \n        Reading comprehension tasks test the...
# 193  1810.02890  \n        Imitation learning has proven to be ...
# 194  1810.02889  \n        We present a framework for generatin...
# 195  1810.02880  \n        In this paper, we introduce a novel ...
# 196  1810.02869  \n        This work is done as part of a maste...
# 197  1810.02862  \n        Haze and smog are among the most com...
# 198  1810.02854  \n        We show that discrete distributions ...
# 199  1810.02851  \n        Auto-encoders compress input data in...
#
#                                             preprossed
# 0    data driven charact anim base motion captur pr...
# 1    build success satisfi modulo theori smt bj rne...
# 2    analys understand languag word boundari base m...
# 3    onlin learn dynam regret metric choos refer op...
# 4    tradit approach hand craft prior sparsiti solv...
# 5    robot requir knowledg object order effici perf...
# 6    although transform translat model vaswani et a...
# 7    chang network structur substanti affect wide n...
# 8    paper aim design quadrotor swarm perform swarm...
# 9    detect build object aerial imag variou applic ...
# 10   widespread adopt continu connect smartphon tab...
# 11   modern natur languag process understand applic...
# 12   consid approxim pattern match problem edit dis...
# 13   meta learn learn learn scienc systemat observ ...
# 14   paper propos new rich resourc enhanc amr align...
# 15   binar neural network bnn recent attract signif...
# 16   present novel parallelis scheme simplifi adapt...
# 17   mani hyperparamet optim hyperopt method assum ...
# 18   work studi problem learn appropri low dimensio...
# 19   paper introduc nsga net evolutionari approach ...
# 20   microblog retriev queri expans essenti obtain ...
# 21   polici search reinforc learn allow robot acqui...
# 22   introduc logic express structur properti autom...
# 23   paper focus show time messag trade off distrib...
# 24   covert commun necessari reveal mere exist mess...
# 25   work introduc innov parallel fulli distribut f...
# 26   brief technic report introduc cinic dataset pl...
# 27   work use percol theori studi feasibl larg scal...
# 28   consid problem increment cycl detect topolog o...
# 29   propos code distribut comput scheme base rapto...
# ..                                                 ...
# 170  present state art comput model across rang seq...
# 171  paper break protocol base diffi hellman decomp...
# 172  higher order connect pattern small induc sub g...
# 173  show shuffl l unicod x e f piecewis testabl la...
# 174  mani domain signific interest captur novel rel...
# 175  learn match function two text sequenc long sta...
# 176  decentr back hyper growth mani blockchain come...
# 177  person identif reid import task requir retriev...
# 178  recent year mani applic driven advanc use mach...
# 179  mechan design studi aggreg renew power produc ...
# 180  paper discuss system consequ central idea proj...
# 181  goal orient learn becom core concept reinforc ...
# 182  novel framework present combin mean field game...
# 183  effort underway ut austin build autonom robot ...
# 184  reinforc learn multi agent scenario import rea...
# 185  propos softwar platform integr method tool mul...
# 186  text mine analyt softwar becom popular littl a...
# 187  present new approach test file system crash co...
# 188  cloud oper requir real time identif heavi hitt...
# 189  note studi practic asymptot stabil nonlinear n...
# 190  mani distanc base algorithm exhibit bia toward...
# 191  consum genet test becom immens popular recent ...
# 192  read comprehens task test abil model process l...
# 193  imit learn proven use mani real world problem ...
# 194  present framework gener natur languag descript...
# 195  paper introduc novel framework combin scientif...
# 196  work done part master thesi project goal integ...
# 197  haze smog among common environment factor impa...
# 198  show discret distribut dimension non neg integ...
# 199  auto encod compress input data latent space re...
#
# [200 rows x 3 columns]

# %% [markdown]
# 해결할 점
# 1. 저 논문 사이트가 적절한가?
# 2. 논문 모든 페이지 별로 가져오는 법(url이 페이지별로 바뀌지 않는다.)
